# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import spotipy
import os
from spotipy.oauth2 import SpotifyClientCredentials
from fuzzywuzzy import fuzz
import dotenv

# load environment variables
dotenv.load_dotenv()

# constants
data_path = '../../raw_data/'

# Get credentials from environment variables
client_id = os.getenv('SPOTIFY_CLIENT_ID')
client_secret = os.getenv('SPOTIFY_CLIENT_SECRET')

# %%
songs_with_attributes_and_lyrics = pd.read_csv(data_path + 'camille/songs_with_attributes_and_lyrics.csv', nrows=10000)
# songs_with_lyrics_and_timestamps = pd.read_csv(data_path + 'camille/songs_with_lyrics_and_timestamps.csv')
songs_with_attributes_and_lyrics
# Out:
#                           id                 name  \
# 0     0Prct5TDjAnEgIqbxcldY9                    !
# 1     2ASl4wirkeYm3OWZxXKYuq                   !!
# 2     69lcggVPmOr9cvPx9kLiiN      !!! - Interlude
# 3     4U7dlZjg1s9pjdppqZy0fm       !!De Repente!!
# 4     4v1IBp3Y3rpkWmWzIlkYju       !!De Repente!!
# ...                      ...                  ...
# 9995  1sULdzB6vSo8XtJKNJG67w                 7.62
# 9996  4xTx0HsUFdGoZzjziLfuG5                 7.62
# 9997  62Yj1WX2JuGDKhslyN490y                 7.62
# 9998  7w77k7yCaDOMe25fYxnzit             7.62 God
# 9999  0hQeRKoNpPrR9doHP8GUPt  7.62's - Radio Edit
#
#                                   album_name  \
# 0                                 UNDEN!ABLE
# 1                                        NaN
# 2                          Where I Belong EP
# 3     Un Palo Al Agua (20 Grandes Canciones)
# 4                             Fuera De Lugar
# ...                                      ...
# 9995                                 HIStory
# 9996                           Cycle of Zero
# 9997                     HIStory, Lost Pages
# 9998                                     NaN
# 9999                     7.62's (Radio Edit)
#
#                                 artists  danceability  energy key  loudness  \
# 0                          ['HELLYEAH']         0.415  0.6050   7   -11.157
# 1                               Yxngxr1         0.788  0.6480   7    -9.135
# 2                            ['Glowie']         0.000  0.0354   7   -20.151
# 3                           ['Rosendo']         0.657  0.8820   5    -6.340
# 4                           ['Rosendo']         0.659  0.8930   5    -8.531
# ...                                 ...           ...     ...  ..       ...
# 9995                      ['YFN Lucci']         0.769  0.6670   2    -6.562
# 9996                       ['Divercia']         0.250  0.8890   4    -7.235
# 9997                      ['YFN Lucci']         0.769  0.6670   2    -6.562
# 9998                       Pooh Shiesty         0.819  0.6510  10    -5.859
# 9999  ['Alabama Nick', 'Chefboy Tyree']         0.772  0.6810   9    -8.242
#
#      mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0       1       0.0575       0.00116          0.838000    0.4710    0.193
# 1       0       0.3150       0.90000          0.000000    0.1760    0.287
# 2       0       0.0000       0.90800          0.000000    0.4790    0.000
# 3       1       0.0385       0.00740          0.000013    0.0474    0.939
# 4       1       0.0411       0.09220          0.000019    0.0534    0.951
# ...   ...          ...           ...               ...       ...      ...
# 9995    1       0.5210       0.12800          0.000000    0.1100    0.329
# 9996    0       0.0585       0.00434          0.848000    0.1270    0.159
# 9997    1       0.5210       0.12800          0.000000    0.1100    0.329
# 9998    0       0.2910       0.00861          0.000000    0.3780    0.522
# 9999    1       0.0922       0.02040          0.014400    0.1090    0.131
#
#         tempo  duration_ms                                             lyrics
# 0     100.059      79500.0  He said he came from Jamaica,\n he owned a cou...
# 1      79.998     114000.0  Fucked a bitch, now she running with my kids\n...
# 2       0.000      11413.0                     Oh, my God, I'm going crazy\n
# 3     123.588     198173.0  Continuamente se extraña la gente si no puede ...
# 4     123.600     199827.0  Continuamente se extraña la gente si no puede ...
# ...       ...          ...                                                ...
# 9995  158.059     172449.0  Pipe that shit up TnT\n Dmac on the fuckin' tr...
# 9996  115.976     292107.0  (Seven... Sixty-two...)\n "Escaping reality as...
# 9997  158.059     172449.0  Pipe that shit up TnT\n Dmac on the fuckin' tr...
# 9998   77.013     177110.0  Once again I'm locked in with TP\n We finna ma...
# 9999  143.008     174672.0  7.62's boy don't f--k round get bruised\n 7.62...
#
# [10000 rows x 17 columns]

# %%
def find_song_album(song_name, artist_name):
    """
    Finds the best matching song and album for a given song name and artist name using Spotify's API.

    Parameters:
    - song_name (str): The name of the song to search for.
    - artist_name (str): The name of the artist to search for.
    - client_id (str): Spotify API client ID.
    - client_secret (str): Spotify API client secret.

    Returns:
    - dict: A dictionary containing the best match's song name, artist name, album name, release date, and match score.
    - None: If no match is found with a score above the threshold.
    """
    
    # Initialize Spotify client with provided credentials
    client_credentials_manager = SpotifyClientCredentials(
        client_id=client_id,
        client_secret=client_secret
    )
    sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
    
    # Construct the search query for Spotify API
    query = f"track:{song_name} artist:{artist_name}"
    # Perform the search with a limit of 50 results
    results = sp.search(q=query, type='track', limit=50)
    
    best_match = None
    highest_score = 0
    
    # Iterate over each track in the search results
    for track in results['tracks']['items']:
        # Calculate the similarity score for the song name
        song_score = fuzz.ratio(song_name.lower(), track['name'].lower())
        # Calculate the similarity score for the artist name
        artist_score = fuzz.ratio(artist_name.lower(), track['artists'][0]['name'].lower())
        
        # Calculate a combined score with weighted contributions from song and artist scores
        combined_score = (song_score * 0.6) + (artist_score * 0.4)
        
        # Update the best match if the current track has a higher combined score
        if combined_score > highest_score:
            highest_score = combined_score
            best_match = track
    
    # Check if a suitable match was found with a score above the threshold
    if best_match and highest_score > 70:  # Threshold for considering a match
        return {
            'song': best_match['name'],
            'artist': best_match['artists'][0]['name'],
            'album': best_match['album']['name'],
            'release_date': best_match['album']['release_date'],
            'match_score': highest_score
        }
    else:
        # Return None if no match meets the threshold criteria
        return None

# %%
import warnings
from tqdm import tqdm

# List to store indices of rows that were skipped
skipped_indices = []

# Making the artists column a list
import ast

def parse_artists(artists):
    if isinstance(artists, str):
        try:
            # Attempt to parse the string as a list
            parsed_artists = ast.literal_eval(artists)
            if isinstance(parsed_artists, list):
                return parsed_artists
        except (ValueError, SyntaxError):
            pass
    return [artists]

songs_with_attributes_and_lyrics['artists'] = songs_with_attributes_and_lyrics['artists'].apply(parse_artists)

# Function to apply to each row
def fill_album_name(row):
    if pd.isna(row['album_name']):
        try:
            result = None
            for artist in row['artists']:
                result = find_song_album(row['name'], artist)
                if result:
                    break
            if result:
                return result['album']
        except Exception as e:
            warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
            skipped_indices.append(row.name)
    return row['album_name']

songs_with_attributes_and_lyrics_cleaned = songs_with_attributes_and_lyrics.copy()

# Apply the function to the DataFrame with tqdm progress bar
tqdm.pandas()
songs_with_attributes_and_lyrics_cleaned['album_name'] = songs_with_attributes_and_lyrics_cleaned.progress_apply(fill_album_name, axis=1)

songs_with_attributes_and_lyrics_cleaned.head()
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]/var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 1 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 5 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 7 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 8 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 10 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 12 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 13 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 15 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 16 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 17 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 18 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 19 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 20 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 21 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 22 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 24 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 25 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 26 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 28 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 29 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 30 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 31 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 32 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 33 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 34 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 37 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 39 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 41 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 42 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 43 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 44 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 45 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 48 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 49 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 51 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 52 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 53 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 58 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 59 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 60 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 61 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 62 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 63 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 65 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 69 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 70 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 72 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 73 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 74 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 75 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 76 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 77 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 78 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 79 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 80 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 83 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 84 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 87 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 88 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 90 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 93 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 94 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 95 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 96 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 97 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 98 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 100 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 101 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 102 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 103 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 105 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 109 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 113 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 114 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 115 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 117 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 118 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 119 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 120 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 121 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 122 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 123 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 124 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 126 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 128 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 129 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 130 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 131 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 132 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 133 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 134 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 135 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 136 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 137 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 138 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 139 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 140 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 144 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 145 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 146 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 147 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 148 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 149 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 151 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 152 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 154 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 155 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 156 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 158 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 159 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 160 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 164 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 166 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 167 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 168 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 169 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 170 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 171 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 173 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 174 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 175 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 176 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 177 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 178 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 179 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 181 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 182 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 183 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 184 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 185 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 186 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 187 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 188 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 195 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 196 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 202 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 203 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 204 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 210 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 211 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 212 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 213 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 214 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 215 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 216 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 217 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 218 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 219 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 220 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 221 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 224 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 225 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 226 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 227 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 228 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 229 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 230 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 232 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 233 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 234 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 235 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 240 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 242 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 243 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 244 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 249 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 254 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 255 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 259 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 262 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 263 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 264 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
# ...
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9907 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9908 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9909 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9910 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9911 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9914 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9915 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9916 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9919 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9923 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9925 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9926 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9927 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9929 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9932 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9933 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9934 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9935 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9940 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9943 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9947 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9948 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9949 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9950 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9952 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9953 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9954 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9955 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9957 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9958 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9959 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9960 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9961 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9962 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9964 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9966 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9967 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9968 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9971 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9972 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9974 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9975 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9976 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9981 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9982 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9988 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9991 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9992 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9994 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# /var/folders/3s/m0cz_jjn4fqfdv71rvtl6bpr0000gn/T/ipykernel_26102/1708121439.py:35: UserWarning: Skipping row at index 9998 due to error: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.
#   warnings.warn(f"Skipping row at index {row.name} due to error: {e}")
# 100%|██████████| 10000/10000 [00:00<00:00, 88003.41it/s]
#                        id             name  \
# 0  0Prct5TDjAnEgIqbxcldY9                !
# 1  2ASl4wirkeYm3OWZxXKYuq               !!
# 2  69lcggVPmOr9cvPx9kLiiN  !!! - Interlude
# 3  4U7dlZjg1s9pjdppqZy0fm   !!De Repente!!
# 4  4v1IBp3Y3rpkWmWzIlkYju   !!De Repente!!
#
#                                album_name     artists  danceability  energy  \
# 0                              UNDEN!ABLE  [HELLYEAH]         0.415  0.6050
# 1                                     NaN   [Yxngxr1]         0.788  0.6480
# 2                       Where I Belong EP    [Glowie]         0.000  0.0354
# 3  Un Palo Al Agua (20 Grandes Canciones)   [Rosendo]         0.657  0.8820
# 4                          Fuera De Lugar   [Rosendo]         0.659  0.8930
#
#   key  loudness mode  speechiness  acousticness  instrumentalness  liveness  \
# 0   7   -11.157    1       0.0575       0.00116          0.838000    0.4710
# 1   7    -9.135    0       0.3150       0.90000          0.000000    0.1760
# 2   7   -20.151    0       0.0000       0.90800          0.000000    0.4790
# 3   5    -6.340    1       0.0385       0.00740          0.000013    0.0474
# 4   5    -8.531    1       0.0411       0.09220          0.000019    0.0534
#
#    valence    tempo  duration_ms  \
# 0    0.193  100.059      79500.0
# 1    0.287   79.998     114000.0
# 2    0.000    0.000      11413.0
# 3    0.939  123.588     198173.0
# 4    0.951  123.600     199827.0
#
#                                               lyrics
# 0  He said he came from Jamaica,\n he owned a cou...
# 1  Fucked a bitch, now she running with my kids\n...
# 2                     Oh, my God, I'm going crazy\n
# 3  Continuamente se extraña la gente si no puede ...
# 4  Continuamente se extraña la gente si no puede ...

# %%
len(skipped_indices)
# Out:
# 5930

# %%
songs_with_attributes_and_lyrics_cleaned.tail()
# Out:
#                           id                 name           album_name  \
# 9995  1sULdzB6vSo8XtJKNJG67w                 7.62              HIStory
# 9996  4xTx0HsUFdGoZzjziLfuG5                 7.62        Cycle of Zero
# 9997  62Yj1WX2JuGDKhslyN490y                 7.62  HIStory, Lost Pages
# 9998  7w77k7yCaDOMe25fYxnzit             7.62 God                  NaN
# 9999  0hQeRKoNpPrR9doHP8GUPt  7.62's - Radio Edit  7.62's (Radio Edit)
#
#                             artists  danceability  energy key  loudness mode  \
# 9995                    [YFN Lucci]         0.769   0.667   2    -6.562    1
# 9996                     [Divercia]         0.250   0.889   4    -7.235    0
# 9997                    [YFN Lucci]         0.769   0.667   2    -6.562    1
# 9998                 [Pooh Shiesty]         0.819   0.651  10    -5.859    0
# 9999  [Alabama Nick, Chefboy Tyree]         0.772   0.681   9    -8.242    1
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 9995       0.5210       0.12800            0.0000     0.110    0.329  158.059
# 9996       0.0585       0.00434            0.8480     0.127    0.159  115.976
# 9997       0.5210       0.12800            0.0000     0.110    0.329  158.059
# 9998       0.2910       0.00861            0.0000     0.378    0.522   77.013
# 9999       0.0922       0.02040            0.0144     0.109    0.131  143.008
#
#       duration_ms                                             lyrics
# 9995     172449.0  Pipe that shit up TnT\n Dmac on the fuckin' tr...
# 9996     292107.0  (Seven... Sixty-two...)\n "Escaping reality as...
# 9997     172449.0  Pipe that shit up TnT\n Dmac on the fuckin' tr...
# 9998     177110.0  Once again I'm locked in with TP\n We finna ma...
# 9999     174672.0  7.62's boy don't f--k round get bruised\n 7.62...

# %%
songs_with_attributes_and_lyrics_cleaned.iloc[0]['artists'][0]
# Out:
# 'HELLYEAH'
